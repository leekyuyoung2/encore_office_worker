# %%
# 함수  : 코드들의 집합
# 리스트 튜플 딕셔너리  : 변수들의 집합
# 변수명 = []  ()   { key:value, }

def add(a, b  ):
    c = a + b
    return c

print ( add( 10,20 ) )
# Out:
# 30

# %%
result = add(10, 20)
print(result)
# Out:
# 30

# %%
# 환율 계산기
# 원화를 입력받아서 달러는 변환하는 함수
def krw_to_usd(krw_amount):
    # 1 use 1400 KRW
    usd_amount = krw_amount / 14000
    print(f'{krw_amount} 는  {usd_amount:.2f} 입니다.')

# %%
print( krw_to_usd(1000000)  )
# Out:
# 1000000 는  71.43 입니다.
# None

# %%
def krw_to_usd(krw_amount):
    # 1 use 1400 KRW
    usd_amount = krw_amount / 14000
    return usd_amount

# %%
krw_amount = 1000000
usd_amount = krw_to_usd(krw_amount)
print(f'{krw_amount} 는  {usd_amount:.2f} 입니다.')
# Out:
# 1000000 는  71.43 입니다.

# %%
# 파일을 읽고 쓰기 
# 오늘의 목표를 입력하세요
goal = input('오늘의 목표를 입력하세요 : ')
# 파일 쓰기 : 입력받은목표를 txt파일에 저장  
with open("today_goal.txt","w") as file:
    file.write(goal)

# %%
# 파일 읽기
with open('today_goal.txt', 'r') as file:
    saved_goal =  file.read()

# %%
print(f'저장된 목표 : {saved_goal}')
# Out:
# 저장된 목표 : 오늘은 함수도 배우고 여러가지 배워서 오후에 평가를 하는 날입니다.

# %%
# CSV 다루기  - pandas
# json 데이터 - 중첩된 dictionary를 문자열로 표현
# 문자열 -> 파이썬 딕셔너리/ 리스트   파싱(변환)
# 파이썬 딕셔너리 /리스트 -> 문자열   덤프(반대)
import json
json_string =  '''
{
    "고객":{
        "이름":"김철수",
        "나이":30
    },
    "다른고객":{
        "이름":"홍길동",
        "나이":35
    }
}
'''
data = json.loads(json_string)  # 문자열 -> 객체
data['고객']
# Out:
# {'이름': '김철수', '나이': 30}

# %%
# 딕셔너리 -> 문자열
output_json = json.dumps(data['고객'],ensure_ascii=False,indent=4)
print(output_json)
# Out:
# {
#     "이름": "김철수",
#     "나이": 30
# }

# %%
# %conda install pandas
# Out:
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: c:\Users\playdata2\miniconda3
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bottleneck-1.4.2           |  py313h2cb717b_0         145 KB
#     intel-openmp-2025.0.0      |    haa95532_1164         2.1 MB
#     mkl-2025.0.0               |     h5da7b33_930       104.7 MB
#     mkl-service-2.5.2          |  py313h0b37514_0          73 KB
#     mkl_fft-1.3.11             |  py313h5810407_1         188 KB
#     mkl_random-1.2.8           |  py313hedd7022_1         280 KB
#     numexpr-2.11.0             |  py313h7660c64_1         208 KB
#     numpy-2.3.3                |  py313h050da96_1          10 KB
# ...

# %%
# 판다스  Pandas (Panel Data)  CSV/Json데이터를 표 형태로 관리
import pandas as pd

# %%
customer_list = [
    ['김철수',30,'서울'],
    ['홍길동',25,'부산'],   
]
columns = ['이름','나이','도시']
df = pd.DataFrame(customer_list,columns=columns)
df.head()
# Out:
#     이름  나이  도시
# 0  김철수  30  서울
# 1  홍길동  25  부산

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      2 non-null      object
#  1   나이      2 non-null      int64
#  2   도시      2 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 180.0+ bytes

# %%
# 외부 csv 파일 읽어오기
import pandas as pd
df = pd.read_csv('C:/office_worker_python_3week/3일차/서울시 식품위생업소 (층) 현황.csv'
                 ,encoding='cp949')
df.head()

# %%
print('안녕\b하세요')
# Out:
# 안하세요

# %%
file_path = 'C:\\office_worker_python_3week\\3일차\\자동차+연간+주행거리(용도별_차종별)_20251025104300.csv'
df = pd.read_csv(file_path,header=4)
df.head()  # 데이터 속성정보 타입정보
# Out:
#    전체   소계  37913630  30161104  1772020  5786446  194060  30664984  26437489  \
# 0  전체  종로구    549354    390885    46888   103719    7862    461223    380686
# 1  전체   중구    596897    429572    50584   104687   12054    494863    387555
# 2  전체  용산구    751601    631917    22059    96373    1252    688388    605112
# 3  전체  성동구   1336704   1038113    72541   221507    4543    947814    789019
# 4  전체  광진구   1142658    906077    41280   191890    3411    977141    823573
#
#    878801  3292792  55902  7248646  3723615  893219  2493654  138158
# 0   33379    46422    736    88131    10199   13509    57297    7127
# 1   43406    60365   3536   102034    42016    7177    44323    8518
# 2   19310    63355    610    63214    26805    2749    33018     641
# 3   21449   135386   1961   388889   249095   51092    86121    2582
# 4   25974   126529   1065   165517    82504   15307    65361    2346

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   전체        25 non-null     object
#  1   소계        25 non-null     object
#  2   37913630  25 non-null     int64
#  3   30161104  25 non-null     int64
#  4   1772020   25 non-null     int64
#  5   5786446   25 non-null     int64
#  6   194060    25 non-null     int64
#  7   30664984  25 non-null     int64
#  8   26437489  25 non-null     int64
#  9   878801    25 non-null     int64
#  10  3292792   25 non-null     int64
#  11  55902     25 non-null     int64
#  12  7248646   25 non-null     int64
#  13  3723615   25 non-null     int64
#  14  893219    25 non-null     int64
#  15  2493654   25 non-null     int64
#  16  138158    25 non-null     int64
# dtypes: int64(15), object(2)
# memory usage: 3.4+ KB

# %%
# 기술통계
df.describe()
# Out:
#            37913630      30161104        1772020        5786446        194060  \
# count  2.500000e+01  2.500000e+01      25.000000      25.000000     25.000000
# mean   1.516545e+06  1.206444e+06   70880.800000  231457.800000   7762.440000
# std    6.284918e+05  5.306712e+05   32684.510638   91990.824446   5966.948069
# min    5.493540e+05  3.908850e+05   22059.000000   96373.000000   1252.000000
# 25%    1.155665e+06  8.984760e+05   49623.000000  181443.000000   4005.000000
# 50%    1.390091e+06  1.101852e+06   65403.000000  218475.000000   5879.000000
# 75%    1.849848e+06  1.492177e+06   84675.000000  272516.000000  10095.000000
# max    2.935602e+06  2.603229e+06  165490.000000  442433.000000  25053.000000
#
#            30664984      26437489        878801       3292792        55902  \
# count  2.500000e+01  2.500000e+01     25.000000      25.00000    25.000000
# mean   1.226599e+06  1.057500e+06  35152.120000  131711.72000  2236.040000
# ...

# %%
2.5e+05
# Out:
# 250000.0

# %%
2.5*100000
# Out:
# 250000.0

# %%
# 공공기관 데이터셋 소상공인 csv 읽기
file_path = 'C:\\office_worker_python_3week\\3일차\\소상공인시장진흥공단_상가업소정보_의료기관_201909.csv'
df = pd.read_csv(file_path,encoding='cp949')
df.head()
# Out:
#      상가업소번호        상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드 상권업종중분류명 상권업종소분류코드  \
# 0  19956873     하나산부인과  NaN         S       의료       S01       병원    S01B10
# 1  20024149   타워광명내과의원  NaN         S       의료       S01       병원    S01B07
# 2  20152277  조정현신경외과의원  NaN         S       의료       S01       병원    S01B15
# 3  20350610   한귀원정신과의원  NaN         S       의료       S01       병원    S01B99
# 4  20364049  더블유스토어수지점  수지점         S       의료       S02   약국/한약방    S02A01
#
#   상권업종소분류명 표준산업분류코드  ...        건물관리번호      건물명                도로명주소  \
# 0     산부인과   Q86201  ...  4.130000e+24  산호한양아파트   경기도 안산시 단원구 달미로 10
# 1    내과/외과   Q86201  ...  1.170000e+24      NaN  서울특별시 강남구 언주로30길 39
# 2     신경외과   Q86201  ...  4.140000e+24    한라프라자    경기도 시흥시 중심상가로 178
# 3     기타병원      NaN  ...  2.650000e+24      NaN    부산광역시 수영구 수영로 688
# 4       약국   G47811  ...  4.150000e+24      NaN   경기도 용인시 수지구 문정로 32
#
#       구우편번호    신우편번호  동정보  층정보  호정보          경도         위도
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91335 entries, 0 to 91334
# Data columns (total 39 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   상가업소번호     91335 non-null  int64
#  1   상호명        91335 non-null  object
#  2   지점명        1346 non-null   object
#  3   상권업종대분류코드  91335 non-null  object
#  4   상권업종대분류명   91335 non-null  object
#  5   상권업종중분류코드  91335 non-null  object
#  6   상권업종중분류명   91335 non-null  object
#  7   상권업종소분류코드  91335 non-null  object
#  8   상권업종소분류명   91335 non-null  object
#  9   표준산업분류코드   86413 non-null  object
#  10  표준산업분류명    86413 non-null  object
#  11  시도코드       90956 non-null  float64
#  12  시도명        90956 non-null  object
#  13  시군구코드      90956 non-null  float64
#  14  시군구명       90956 non-null  object
#  15  행정동코드      91335 non-null  int64
#  16  행정동명       90956 non-null  object
#  17  법정동코드      91280 non-null  float64
#  18  법정동명       91280 non-null  object
# ...

# %%
# 판다스에서는 비어있는 데이터를 결측치 NA 라고함
df.isna().sum()
# Out:
# 상가업소번호           0
# 상호명              0
# 지점명          89989
# 상권업종대분류코드        0
# 상권업종대분류명         0
# 상권업종중분류코드        0
# 상권업종중분류명         0
# 상권업종소분류코드        0
# 상권업종소분류명         0
# 표준산업분류코드      4922
# 표준산업분류명       4922
# 시도코드           379
# 시도명            379
# 시군구코드          379
# 시군구명           379
# 행정동코드            0
# 행정동명           379
# 법정동코드           55
# 법정동명            55
# 지번코드             0
# 대지구분코드           0
# 대지구분명            0
# 지번본번지            0
# 지번부번지        19256
# 지번주소             0
# 도로명코드            0
# 도로명              0
# 건물본번지            0
# 건물부번지        80731
# 건물관리번호           0
# 건물명          44882
# 도로명주소            0
# 구우편번호           12
# 신우편번호            2
# 동정보          83929
# 층정보          47346
# 호정보          75898
# 경도               0
# 위도               0
# dtype: int64

# %%
df.isna().mean()
# Out:
# 상가업소번호       0.000000
# 상호명          0.000000
# 지점명          0.985263
# 상권업종대분류코드    0.000000
# 상권업종대분류명     0.000000
# 상권업종중분류코드    0.000000
# 상권업종중분류명     0.000000
# 상권업종소분류코드    0.000000
# 상권업종소분류명     0.000000
# 표준산업분류코드     0.053890
# 표준산업분류명      0.053890
# 시도코드         0.004150
# 시도명          0.004150
# 시군구코드        0.004150
# 시군구명         0.004150
# 행정동코드        0.000000
# 행정동명         0.004150
# 법정동코드        0.000602
# 법정동명         0.000602
# 지번코드         0.000000
# 대지구분코드       0.000000
# 대지구분명        0.000000
# 지번본번지        0.000000
# 지번부번지        0.210828
# 지번주소         0.000000
# 도로명코드        0.000000
# 도로명          0.000000
# 건물본번지        0.000000
# 건물부번지        0.883900
# 건물관리번호       0.000000
# 건물명          0.491400
# 도로명주소        0.000000
# 구우편번호        0.000131
# 신우편번호        0.000022
# 동정보          0.918914
# 층정보          0.518377
# 호정보          0.830985
# 경도           0.000000
# 위도           0.000000
# dtype: float64

# %%
# %conda install missingno
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: c:\Users\playdata2\miniconda3
#
#   added / updated specs:
#     - missingno
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     contourpy-1.3.1            |  py313h214f63a_0         234 KB
#     fonttools-4.60.1           |  py313h02ab6af_0         3.6 MB
#     kiwisolver-1.4.8           |  py313h5da7b33_0          63 KB
#     lcms2-2.16                 |       hb4a4139_0         566 KB
#     lerc-3.0                   |       hd77b12b_0         120 KB
#     libdeflate-1.17            |       h2bbff1b_1         153 KB
#     libpng-1.6.50              |       h46444df_0         237 KB
#     libtiff-4.5.1              |       hd77b12b_0         1.1 MB
#     matplotlib-base-3.10.6     |  py313h26e45b9_0         7.9 MB
# ...

# %%
import missingno as msno

# %%
msno.matrix(df)
# Out:
# <Axes: >
# C:\Users\playdata2\AppData\Roaming\Python\Python313\site-packages\IPython\core\events.py:82: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\playdata2\AppData\Roaming\Python\Python313\site-packages\IPython\core\events.py:82: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\playdata2\AppData\Roaming\Python\Python313\site-packages\IPython\core\events.py:82: UserWarning: Glyph 50629 (\N{HANGUL SYLLABLE EOB}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# C:\Users\playdata2\AppData\Roaming\Python\Python313\site-packages\IPython\core\events.py:82: UserWarning: Glyph 49548 (\N{HANGUL SYLLABLE SO}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# ...

# %%
selected_cols = ['상호명','상권업종대분류명','상권업종중분류명','상권업종소분류명',
                 '도로명주소','위도','경도']
df2 = df.loc[ : , selected_cols  ]
df2.head()
# Out:
#          상호명 상권업종대분류명 상권업종중분류명 상권업종소분류명                도로명주소         위도  \
# 0     하나산부인과       의료       병원     산부인과   경기도 안산시 단원구 달미로 10  37.336344
# 1   타워광명내과의원       의료       병원    내과/외과  서울특별시 강남구 언주로30길 39  37.488742
# 2  조정현신경외과의원       의료       병원     신경외과    경기도 시흥시 중심상가로 178  37.344955
# 3   한귀원정신과의원       의료       병원     기타병원    부산광역시 수영구 수영로 688  35.166872
# 4  더블유스토어수지점       의료   약국/한약방       약국   경기도 용인시 수지구 문정로 32  37.323528
#
#            경도
# 0  126.814295
# 1  127.053198
# 2  126.734841
# 3  129.115438
# 4  127.095522

# %%
# 파생변수
'경기도 안산시 단원구 달미로 10'.split()
# Out:
# ['경기도', '안산시', '단원구', '달미로', '10']

# %%
city = []
for row in df2['도로명주소'].str.split():
    city.append(row[0])

# %%
df2['시군구'] = city

# %%
df2.head()
# Out:
#          상호명 상권업종대분류명 상권업종중분류명 상권업종소분류명                도로명주소         위도  \
# 0     하나산부인과       의료       병원     산부인과   경기도 안산시 단원구 달미로 10  37.336344
# 1   타워광명내과의원       의료       병원    내과/외과  서울특별시 강남구 언주로30길 39  37.488742
# 2  조정현신경외과의원       의료       병원     신경외과    경기도 시흥시 중심상가로 178  37.344955
# 3   한귀원정신과의원       의료       병원     기타병원    부산광역시 수영구 수영로 688  35.166872
# 4  더블유스토어수지점       의료   약국/한약방       약국   경기도 용인시 수지구 문정로 32  37.323528
#
#            경도    시군구
# 0  126.814295    경기도
# 1  127.053198  서울특별시
# 2  126.734841    경기도
# 3  129.115438  부산광역시
# 4  127.095522    경기도
