# %%
sample_lists = [1,2,3,4,5]
boolean_lists = [True,True,False,False,False]
sample_lists[boolean_lists]

# %%
import numpy as np
sample_lists = np.array([1,2,3,4,5])
boolean_lists = [True,True,False,False,False]
sample_lists[boolean_lists]
# Out:
# array([1, 2])

# %%
a = np.array([True,False,True])
b = np.array([False,False,True])

a & b
# Out:
# array([False, False,  True])

# %%
import pandas as pd
url = 'sample_superstore_data.csv'
df = pd.read_csv(url)

# %%
# NA 결측치.. 비어 있거나 pd.NA로 셋팅된 값

df['Profit'].notna()
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
#       ...
# 95    True
# 96    True
# 97    True
# 98    True
# 99    True
# Name: Profit, Length: 100, dtype: bool

# %%
df[df['Profit'].isna()]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Region, Category, Sub-Category, Sales, Quantity, Discount, Profit]
# Index: []

# %%
df_Furniture =  df[df.Category == 'Furniture']
len(df_Furniture)
# Out:
# 33

# %%
df_Furniture.shape
# Out:
# (33, 18)

# %%
df[~df.Category.isin(['Office Supplies','Technology'])]
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        1  CA-2020-000001  01/03/2020  06/03/2020  Standard Class
# 1        2  CA-2020-000002  01/03/2020  06/03/2020  Standard Class
# 2        3  CA-2020-000003  01/03/2020  06/03/2020  Standard Class
# 3        4  CA-2020-000004  01/03/2020  06/03/2020  Standard Class
# 4        5  CA-2020-000005  01/03/2020  06/03/2020  Standard Class
# 5        6  CA-2020-000006  01/03/2020  06/03/2020  Standard Class
# 6        7  CA-2020-000007  01/03/2020  06/03/2020  Standard Class
# 7        8  CA-2020-000008  01/03/2020  06/03/2020  Standard Class
# 8        9  CA-2020-000009  01/03/2020  06/03/2020  Standard Class
# 9       10  CA-2020-000010  01/03/2020  06/03/2020  Standard Class
# 10      11  CA-2020-000011  01/03/2020  06/03/2020  Standard Class
# 11      12  CA-2020-000012  01/03/2020  06/03/2020  Standard Class
# 12      13  CA-2020-000013  01/03/2020  06/03/2020  Standard Class
# ...

# %%
df.loc[3,'Sub-Category'] = pd.NA
df[df['Sub-Category'].str.contains('Chairs',na=False)]
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        1  CA-2020-000001  01/03/2020  06/03/2020  Standard Class
# 1        2  CA-2020-000002  01/03/2020  06/03/2020  Standard Class
# 2        3  CA-2020-000003  01/03/2020  06/03/2020  Standard Class
# 4        5  CA-2020-000005  01/03/2020  06/03/2020  Standard Class
# 5        6  CA-2020-000006  01/03/2020  06/03/2020  Standard Class
# 6        7  CA-2020-000007  01/03/2020  06/03/2020  Standard Class
# 7        8  CA-2020-000008  01/03/2020  06/03/2020  Standard Class
# 8        9  CA-2020-000009  01/03/2020  06/03/2020  Standard Class
# 9       10  CA-2020-000010  01/03/2020  06/03/2020  Standard Class
# 10      11  CA-2020-000011  01/03/2020  06/03/2020  Standard Class
# 11      12  CA-2020-000012  01/03/2020  06/03/2020  Standard Class
# 12      13  CA-2020-000013  01/03/2020  06/03/2020  Standard Class
# 13      14  CA-2020-000014  01/03/2020  06/03/2020  Standard Class
# ...

# %%
pd.to_datetime(df['Order Date']).dt.year
# Out:
# 0     2020
# 1     2020
# 2     2020
# 3     2020
# 4     2020
#       ...
# 95    2020
# 96    2020
# 97    2020
# 98    2020
# 99    2020
# Name: Order Date, Length: 100, dtype: int32

# %%
df['Order Date'].str.split('/')
# Out:
# 0     [01, 03, 2020]
# 1     [01, 03, 2020]
# 2     [01, 03, 2020]
# 3     [01, 03, 2020]
# 4     [01, 03, 2020]
#            ...
# 95    [01, 03, 2020]
# 96    [01, 03, 2020]
# 97    [01, 03, 2020]
# 98    [01, 03, 2020]
# 99    [01, 03, 2020]
# Name: Order Date, Length: 100, dtype: object
