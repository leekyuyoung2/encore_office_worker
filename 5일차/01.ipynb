# %%
import pandas as pd
url = 'sample_superstore_data.csv'
df = pd.read_csv(url)
df.set_index(['Order ID'], inplace=True)

# %%
df.iloc[1]
# Out:
# Row ID                        2
# Order Date           01/03/2020
# Ship Date            06/03/2020
# Ship Mode        Standard Class
# Customer ID            CG-12101
# Customer Name        Customer 1
# Segment                Consumer
# Country           United States
# City                   New York
# State                  New York
# Region                     East
# Category              Furniture
# Sub-Category             Chairs
# Sales                   1199.99
# Quantity                      5
# Discount                   0.15
# Profit                   299.99
# Name: CA-2020-000002, dtype: object

# %%
df.loc['CA-2020-000002']
# Out:
# Row ID                        2
# Order Date           01/03/2020
# Ship Date            06/03/2020
# Ship Mode        Standard Class
# Customer ID            CG-12101
# Customer Name        Customer 1
# Segment                Consumer
# Country           United States
# City                   New York
# State                  New York
# Region                     East
# Category              Furniture
# Sub-Category             Chairs
# Sales                   1199.99
# Quantity                      5
# Discount                   0.15
# Profit                   299.99
# Name: CA-2020-000002, dtype: object

# %%
df.head()
# Out:
#                 Row ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Order ID
# CA-2020-000001       1  01/03/2020  06/03/2020  Standard Class    CG-12100
# CA-2020-000002       2  01/03/2020  06/03/2020  Standard Class    CG-12101
# CA-2020-000003       3  01/03/2020  06/03/2020  Standard Class    CG-12102
# CA-2020-000004       4  01/03/2020  06/03/2020  Standard Class    CG-12103
# CA-2020-000005       5  01/03/2020  06/03/2020  Standard Class    CG-12104
#
#                Customer Name   Segment        Country      City     State  \
# Order ID
# CA-2020-000001    Customer 0  Consumer  United States  New York  New York
# CA-2020-000002    Customer 1  Consumer  United States  New York  New York
# CA-2020-000003    Customer 2  Consumer  United States  New York  New York
# CA-2020-000004    Customer 3  Consumer  United States  New York  New York
# CA-2020-000005    Customer 4  Consumer  United States  New York  New York
#
# ...

# %%
df.loc['CA-2020-000002':'CA-2020-000003'  ,'Ship Mode' :'Segment' ]
# Out:
#                      Ship Mode Customer ID Customer Name   Segment
# Order ID
# CA-2020-000002  Standard Class    CG-12101    Customer 1  Consumer
# CA-2020-000003  Standard Class    CG-12102    Customer 2  Consumer

# %%
df.iloc[1:3 , 3:7 ]
# Out:
#                      Ship Mode Customer ID Customer Name   Segment
# Order ID
# CA-2020-000002  Standard Class    CG-12101    Customer 1  Consumer
# CA-2020-000003  Standard Class    CG-12102    Customer 2  Consumer

# %%
df.reset_index()
# Out:
#           Order ID  Row ID  Order Date   Ship Date       Ship Mode  \
# 0   CA-2020-000001       1  01/03/2020  06/03/2020  Standard Class
# 1   CA-2020-000002       2  01/03/2020  06/03/2020  Standard Class
# 2   CA-2020-000003       3  01/03/2020  06/03/2020  Standard Class
# 3   CA-2020-000004       4  01/03/2020  06/03/2020  Standard Class
# 4   CA-2020-000005       5  01/03/2020  06/03/2020  Standard Class
# ..             ...     ...         ...         ...             ...
# 95  CA-2020-000096      96  01/03/2020  06/03/2020     First Class
# 96  CA-2020-000097      97  01/03/2020  06/03/2020     First Class
# 97  CA-2020-000098      98  01/03/2020  06/03/2020     First Class
# 98  CA-2020-000099      99  01/03/2020  06/03/2020     First Class
# 99  CA-2020-000100     100  01/03/2020  06/03/2020     First Class
#
#    Customer ID Customer Name      Segment        Country      City     State  \
# 0     CG-12100    Customer 0     Consumer  United States  New York  New York
# ...
